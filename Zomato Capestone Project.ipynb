# %% [markdown]
# #                                     ____Zomato Dining Restaurants Analysis In Chennai____

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
import pandas as pd
import time
from webdriver_manager.chrome import ChromeDriverManager
# Set up Selenium
options = Options()
# options.add_argument("--headless")  # Uncomment to run in headless mode
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=options)

def scrape_product_details(product_url):
    driver.get(product_url)
    time.sleep(3)  # Increased wait time for page to load
    
    # Extract product details
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    
    # Modify these selectors based on the product page structure
    name = soup.find('h1', class_='sc-7kepeu-0 sc-iSDuPN fwzNdh').text.strip() if soup.find('h1', class_='sc-7kepeu-0 sc-iSDuPN fwzNdh') else 'N/A'
    cuisine = soup.find('div', class_='sc-gVyKpa fXdtVd').text.strip() if soup.find('div', class_='sc-gVyKpa fXdtVd') else 'N/A'
    address = soup.find('a', class_='sc-clNaTc vNCcy').text.strip() if soup.find('a', class_='sc-clNaTc vNCcy') else 'N/A'
    opening = soup.find('span', class_='sc-kasBVs dfwCXs').text.strip() if soup.find('span', class_='sc-kasBVs dfwCXs') else 'N/A'
    rating = soup.find('div', class_='sc-1q7bklc-1 cILgox').text.strip() if soup.find('div', class_='sc-1q7bklc-1 cILgox') else 'N/A'
    average = soup.find('div', class_='sc-bEjcJn ePRRqr').text.strip() if soup.find('div', class_='sc-bEjcJn ePRRqr') else 'N/A'
   
    return {
        'Product Name': name,
        'Cuisines': cuisine,
        'Address': address,
        'Opening and Closing Time': opening,
        'Ratings': rating,
        'Average Cost': average
    }

def scroll_to_load_content():
    # Scroll to the bottom of the page repeatedly with a delay until no new content is loaded
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)  # Increased wait time for new content to load
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:  # If no new content is loaded, break
            break
        last_height = new_height

def scrape_books(url):
    driver.get(url)
    time.sleep(3)  # Initial wait for the page to load fully
    book_data = []

    # Scroll and load all content
    scroll_to_load_content()

    # Parse the loaded page content with BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    books = soup.find_all('div', class_='sc-1mo3ldo-0 sc-jGkVzM BXbKf')

    for book in books:
        try:
            # Check if the product link element exists before trying to get 'href'
            link_tag = book.find('a', class_='sc-hPeUyl cKQNlu')
            if link_tag and 'href' in link_tag.attrs:
                product_link = link_tag['href']
                full_product_url = 'https://www.zomato.com' + product_link

                # Scrape product details
                product_details = scrape_product_details(full_product_url)
                print(product_details)
                book_data.append(product_details)
            else:
                print("Product link not found for this book.")

        except Exception as e:
            print(f"Error processing book: {e}")

    # Convert list to DataFrame
    df = pd.DataFrame(book_data)
    return df

# Start scraping from the first page
df_books = scrape_books('https://www.zomato.com/chennai/dine-out')
driver.quit()  # Close the browser when done

# Save the DataFrame to a CSV file
df_books.to_csv('zomato_books1.csv', index=False)
print("Data saved to zomato_books1.csv")
# Out:
# Product link not found for this book.
# {'Product Name': 'Secret Story', 'Cuisines': 'North Indian, Chinese, Italian, Fast Food', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'TapasMe', 'Cuisines': 'Asian, European, Continental, Desserts, Beverages', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '12noon – 11:30pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹1,500 for two'}
# {'Product Name': 'Lord of the Drinks', 'Cuisines': 'Italian, Continental, North Indian, Japanese, Desserts, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Goldman’s Steakhouse', 'Cuisines': 'American, Mexican, Steak, Fast Food, Beverages, Desserts', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11am – 11:30pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Sin & Tonic', 'Cuisines': 'North Indian, Italian, BBQ, Wraps, Pizza, Desserts, Bar Food', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '12noon – 12midnight (Today)', 'Ratings': '4.5', 'Average Cost': '₹2,700 for two'}
# {'Product Name': 'Colony - The Raintree', 'Cuisines': 'Italian, North Indian, South Indian, Continental, Fast Food, Beverages, Desserts', 'Address': 'The Raintree, Alwarpet, Chennai', 'Opening and Closing Time': '7am – 10:45pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹3,300 for two'}
# {'Product Name': 'Hard Rock Cafe', 'Cuisines': 'American, Continental, Italian, Wraps, Burger, Desserts, Fast Food, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Mathsya', 'Cuisines': 'South Indian, North Indian, Chinese, Fast Food, Desserts, Beverages, Shake', 'Address': 'Adyar, Chennai', 'Opening and Closing Time': '7am – 11pm (Today)', 'Ratings': '3.7', 'Average Cost': '₹950 for two'}
# {'Product Name': 'Marmoris Beach Lounge', 'Cuisines': 'North Indian, Chinese, Continental, Italian, Beverages, Desserts', 'Address': 'Mahabalipuram, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.6', 'Average Cost': '₹1,500 for two'}
# {'Product Name': 'Grand Anjappar', 'Cuisines': 'Biryani, Chinese', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '12midnight – 2am, 11:30am – 12midnight (Today)', 'Ratings': '4.4', 'Average Cost': '₹200 for two'}
# {'Product Name': 'The Living Room', 'Cuisines': 'North Indian, Pasta, Italian, Fast Food, Pizza, Desserts', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'The Mayflower', 'Cuisines': 'Continental', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Hub at ECR', 'Cuisines': 'North Indian, Continental, Italian, Pizza, Kebab, Seafood', 'Address': 'Injambakkam, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Message In A Bottle', 'Cuisines': 'Bar Food, North Indian, Chinese, Continental, Beverages', 'Address': 'Egmore, Chennai', 'Opening and Closing Time': '11am – 11:30pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Asvah 24', 'Cuisines': 'French, Italian, Continental, Pasta, Desserts, Coffee, Beverages', 'Address': 'Neelangarai, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Dhaba - Estd 1986 Delhi', 'Cuisines': 'North Indian, Mughlai, Biryani, Kebab, Desserts', 'Address': 'Ispahani Centre, Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 11:30pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,500 for two'}
# {'Product Name': '101 Resto Bar', 'Cuisines': 'Asian, Continental, North Indian, Chinese, Desserts, Bar Food, Beverages', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Cocomaya', 'Cuisines': 'Mexican, Italian, Burger, Desserts, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '4pm – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Zonkk', 'Cuisines': 'Continental, Salad, Street Food, Pizza, Pasta, Bar Food', 'Address': 'Medavakkam, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'AsianKatha', 'Cuisines': 'Japanese, Singaporean, Chinese, Asian, Indonesian, Thai, Burmese, Malaysian', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': 'Opens at 6:30pm', 'Ratings': '4.5', 'Average Cost': '₹1,500 for two'}
# {'Product Name': 'EGCO', 'Cuisines': 'Cafe, Coffee, Fast Food', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '7:30am – 9:30pm (Today)', 'Ratings': '3.5', 'Average Cost': '₹1,255 for two'}
# {'Product Name': 'Off The Record', 'Cuisines': 'European, Continental, North Indian, Pizza, Pasta, Desserts, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11am – 11:45pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Sage and Lavender Bistro', 'Cuisines': 'Continental, European, Asian, Salad', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'The Thief', 'Cuisines': 'North Indian, Continental, Italian, Asian, Thai, Beverages, Desserts', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹2,600 for two'}
# {'Product Name': 'Soy Soi', 'Cuisines': 'Sushi, Asian, Seafood, Japanese, Thai, Desserts, Beverages', 'Address': 'Kotturpuram, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.7', 'Average Cost': '₹1,700 for two'}
# {'Product Name': 'Filli Cafe', 'Cuisines': 'Cafe, Tea, Italian', 'Address': 'Thousand Lights, Chennai', 'Opening and Closing Time': '10am – 11:15pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹800 for two'}
# {'Product Name': 'Kipling Cafe', 'Cuisines': 'Continental, Asian, North Indian, Chinese, Pizza, Desserts, Beverages', 'Address': 'Kipling, East Coast Road (ECR), Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,600 for two'}
# {'Product Name': 'The Entrance Cafe', 'Cuisines': 'Cafe, Coffee, Fast Food, Beverages', 'Address': 'Kilpauk, Chennai', 'Opening and Closing Time': '8:30am – 10:30pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹1,800 for two'}
# {'Product Name': "Watson's", 'Cuisines': 'South Indian, North Indian, Seafood, Pizza, Fast Food, Beverages', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '11am – 11:30pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,700 for two'}
# {'Product Name': 'The Summer House Eatery', 'Cuisines': 'Cafe, Mexican, Italian, Continental, Fast Food, Desserts, Beverages', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '12noon – 10pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'Bayroot', 'Cuisines': 'North Indian, Chinese, Oriental, Arabian, Sushi, Pasta, Desserts', 'Address': 'Palavakkam, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Paati Veedu', 'Cuisines': 'South Indian, Desserts, Beverages', 'Address': 'Paati Veedu, T.Nagar, Chennai', 'Opening and Closing Time': 'Opens at 7pm', 'Ratings': '4.2', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Q Bar - Hilton Chennai', 'Cuisines': 'Continental, Finger Food', 'Address': 'Hilton Chennai, Guindy, Chennai', 'Opening and Closing Time': 'Opens at 5pm', 'Ratings': '4.2', 'Average Cost': '₹4,000 for two'}
# {'Product Name': 'The Cycle Gap', 'Cuisines': 'Andhra, North Indian, Continental, Asian, Oriental, Italian, Desserts, Beverages', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Toscano', 'Cuisines': 'Italian, Pizza, Pasta, Continental, Seafood, Steak, Beverages', 'Address': 'Phoenix Market City, Velachery, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.6', 'Average Cost': '₹1,600 for two'}
# {'Product Name': 'Bazaar - All Day Diner - Grand by GRT Hotels', 'Cuisines': 'North Indian, South Indian, Continental, Asian, Desserts, Beverages', 'Address': 'Grand by GRT Hotels, Chennai', 'Opening and Closing Time': '7am – 11pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹3,300 for two'}
# {'Product Name': 'Lazy Leopard', 'Cuisines': 'Pizza, Italian, Continental, Desserts, Cafe, Beverages', 'Address': 'Gopalapuram, Chennai', 'Opening and Closing Time': '12noon – 4pm, 7pm – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,500 for two'}
# {'Product Name': 'Sky | Curated Asian Dining - The Residency Towers', 'Cuisines': 'Asian, North Indian, Chinese, Biryani, Sushi, Desserts', 'Address': 'The Residency Towers, T. Nagar, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Double Roti', 'Cuisines': 'Burger, Continental, Pizza, Italian, Mexican, Beverages', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '8am – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,100 for two'}
# {'Product Name': 'Above Sea Level - The Raintree', 'Cuisines': 'Continental, Mughlai, North Indian, Kebab, Italian, Desserts', 'Address': 'The Raintree, Alwarpet, Chennai', 'Opening and Closing Time': 'Opens at 7pm', 'Ratings': '4.2', 'Average Cost': '₹3,500 for two'}
# {'Product Name': 'Lafayette By Mug Cakes', 'Cuisines': 'Italian, American, Desserts', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 10:30pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,100 for two'}
# {'Product Name': 'Mezze', 'Cuisines': 'Middle Eastern, Continental, Fast Food, Beverages, Desserts', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '11:30am – 10:30pm (Today)', 'Ratings': '4.7', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'India Brew House', 'Cuisines': 'Cafe, Coffee, Shake, Beverages', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '10:30am – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹450 for two'}
# {'Product Name': 'Take 2', 'Cuisines': 'North Indian, Chinese, Continental, Bar Food', 'Address': 'Kodambakkam, Chennai', 'Opening and Closing Time': '12noon – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,700 for two'}
# {'Product Name': 'Hola', 'Cuisines': 'Chinese, North Indian, Italian, Mexican, Sichuan, Desserts, Beverages', 'Address': 'Citadines, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,400 for two'}
# {'Product Name': 'Woodlands Drive In', 'Cuisines': 'South Indian, North Indian, Chinese, Desserts, Beverages', 'Address': 'Arumbakkam, Chennai', 'Opening and Closing Time': '8am – 10:45pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Kobe Sizzlers', 'Cuisines': 'Salad, Continental, Sandwich, Burger, Fast Food, Chinese, Ice Cream, Beverages', 'Address': 'VR Mall, Anna Nagar, Chennai', 'Opening and Closing Time': '11:30am – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,300 for two'}
# {'Product Name': 'Monkey Bar', 'Cuisines': 'North Indian, Burger, Pizza, Italian, Bar Food', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Copper Chimney', 'Cuisines': 'North Indian, Mughlai, Biryani, Kebab, Desserts, Beverages', 'Address': 'Phoenix Market City, Velachery, Chennai', 'Opening and Closing Time': '12noon – 4pm, 6:30pm – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,600 for two'}
# {'Product Name': 'Limited Edition - The Premium Lounge', 'Cuisines': 'Continental, Italian', 'Address': 'Adyar, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,500 for two'}
# {'Product Name': "Chop 'N' Stix", 'Cuisines': 'Chinese, Asian, Sichuan', 'Address': 'Porur, Chennai', 'Opening and Closing Time': '11:30am – 11pm (Today)', 'Ratings': '3.3', 'Average Cost': '₹550 for two'}
# {'Product Name': 'Middle Of NoWhere', 'Cuisines': 'Continental, South Indian, North Indian, Finger Food, Asian, Sichuan, Beverages', 'Address': 'Mogappair, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Sugosugo', 'Cuisines': 'Italian, Pizza, Pasta, Desserts', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '11:30am – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'The Mayflower', 'Cuisines': 'Italian, Asian, Continental, Pizza, Fast Food, Healthy Food, Desserts, Beverages', 'Address': 'RK Salai (Cathedral Road), Chennai', 'Opening and Closing Time': '11am – 10:30pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'Cafe Manana', 'Cuisines': 'Cafe', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': 'New', 'Average Cost': '₹800 for two'}
# {'Product Name': 'Steam & Whistles - Grand by GRT Hotels', 'Cuisines': 'Finger Food, Japanese, Asian, Chinese, North Indian, South Indian', 'Address': 'Grand by GRT Hotels, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.6', 'Average Cost': '₹3,000 for two'}
# {'Product Name': 'Odin’s Galley', 'Cuisines': 'North Indian, Chinese, Mexican, Momos, Bar Food, Desserts, Beverages', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '11am – 12midnight (Today)', 'Ratings': '4.3', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Sicily', 'Cuisines': 'Italian, Pasta', 'Address': 'Adyar, Chennai', 'Opening and Closing Time': '12:30pm – 11:30pm (Today)', 'Ratings': 'New', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'TIKI TAKO', 'Cuisines': 'Chinese, Burger, Sandwich, Bar Food, Desserts', 'Address': 'Okkiyampet, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Nandhana Palace', 'Cuisines': 'Biryani, North Indian, Andhra, Chinese', 'Address': 'Triplicane, Chennai', 'Opening and Closing Time': '12midnight – 2am, 10am – 12midnight (Today)', 'Ratings': '4.3', 'Average Cost': '₹600 for two'}
# {'Product Name': 'Locofeast', 'Cuisines': 'North Indian, Continental, Seafood, Fast Food, Shake, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11:30am – 4pm, 6:30pm – 10:30pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹950 for two'}
# {'Product Name': "Abid's", 'Cuisines': 'Arabian, Biryani, Hyderabadi, North Indian, Seafood, Oriental, Desserts, Beverages', 'Address': 'Chetpet, Chennai', 'Opening and Closing Time': '12:30pm – 10:30pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹1,700 for two'}
# {'Product Name': 'Sky7 Restobar', 'Cuisines': 'Bar Food, South Indian', 'Address': 'Arumbakkam, Chennai', 'Opening and Closing Time': '11am – 12midnight (Today)', 'Ratings': '3.7', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Halt', 'Cuisines': 'Coffee, Beverages, Sandwich', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '10am – 11:30pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹400 for two'}
# {'Product Name': 'Shaack', 'Cuisines': 'Asian, Continental, Italian, South Indian, Desserts, Beverages, Sichuan', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '12noon – 2am (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,100 for two'}
# {'Product Name': 'The Weekend', 'Cuisines': 'South Indian, North Indian, Chinese, Asian, Pizza, Pasta, Desserts', 'Address': 'St. Thomas Mount, Chennai', 'Opening and Closing Time': '11am – 10:30pm (Today)', 'Ratings': 'New', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'Burger King', 'Cuisines': 'Burger, Fast Food, Beverages', 'Address': 'Forum Vijaya Mall, Vadapalani, Chennai', 'Opening and Closing Time': '10am – 11pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹300 for two'}
# {'Product Name': 'Chinese Wok', 'Cuisines': 'Chinese, Momos', 'Address': 'Porur, Chennai', 'Opening and Closing Time': '12midnight – 2am, 11am – 12midnight (Today)', 'Ratings': '4.0', 'Average Cost': '₹700 for two'}
# {'Product Name': 'Una Villa', 'Cuisines': 'Italian, Pasta, Sandwich, Pizza, Burger, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '10am – 10pm (Today)', 'Ratings': 'New', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Royal Palate', 'Cuisines': 'Continental, European, South Indian, North Indian, Chinese, Desserts', 'Address': 'Ambica Empire, Vadapalani, Chennai', 'Opening and Closing Time': '24 Hours (Today)', 'Ratings': '3.5', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Truly Herbivore', 'Cuisines': 'North Indian, South Indian, Continental, Italian, Maharashtrian, Desserts, Beverages', 'Address': 'Ashok Nagar, Chennai', 'Opening and Closing Time': '24 Hours (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Mokchi Cafe', 'Cuisines': 'Asian, Salad, Continental, Ice Cream, Desserts, Beverages', 'Address': 'Madipakkam, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'Spice It - IBIS Chennai OMR', 'Cuisines': 'Tibetan, Mexican, North Indian, Chinese', 'Address': 'IBIS Chennai, OMR, Chennai', 'Opening and Closing Time': '6:30am – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,300 for two'}
# {'Product Name': 'Innings Cafe', 'Cuisines': 'Cafe, Coffee, Continental, Fast Food, Desserts, Shake, Beverages', 'Address': 'Madipakkam, Chennai', 'Opening and Closing Time': '2pm – 2am (Today)', 'Ratings': '4.2', 'Average Cost': '₹500 for two'}
# {'Product Name': 'The Gin Joint', 'Cuisines': 'South Indian, Continental, Pizza, Chinese, Asian', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Anjappar', 'Cuisines': 'South Indian, Beverages', 'Address': 'GST Road, Chennai', 'Opening and Closing Time': '11:30am – 11:30pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹700 for two'}
# {'Product Name': "Kim's BBQ", 'Cuisines': 'Korean, Japanese, Sushi, Rolls, Salad', 'Address': 'Kotturpuram, Chennai', 'Opening and Closing Time': '11am – 4pm, 6pm – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,500 for two'}
# {'Product Name': 'Achayathis Restaurant', 'Cuisines': 'Kerala, South Indian', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '7:30am – 11pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹950 for two'}
# {'Product Name': 'Hungry Cars', 'Cuisines': 'Chinese, Biryani, Continental', 'Address': 'Egatoor, Chennai', 'Opening and Closing Time': '11:30am – 11pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Spectra - The Leela Palace', 'Cuisines': 'North Indian, Asian, Mediterranean, Continental, Italian', 'Address': 'The Leela Palace, MRC Nagar, Chennai', 'Opening and Closing Time': '7am – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹4,700 for two'}
# {'Product Name': 'The Leather Bar - The Park', 'Cuisines': 'Bar Food, Italian, North Indian', 'Address': 'The Park, Nungambakkam, Chennai', 'Opening and Closing Time': '11am – 1am (Today)', 'Ratings': '4.2', 'Average Cost': '₹3,500 for two'}
# {'Product Name': 'Pronto The Coffee People', 'Cuisines': 'Cafe, Coffee, Shake, Beverages, Fast Food, North Indian, Chinese', 'Address': 'Selaiyur, Chennai', 'Opening and Closing Time': '11am – 10:30pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹450 for two'}
# {'Product Name': 'Jiiggys', 'Cuisines': 'Mexican, Fast Food', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '1pm – 12midnight (Today)', 'Ratings': '3.0', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Lazio', 'Cuisines': 'Continental, Asian, Pasta, Pizza, Chinese, Desserts', 'Address': 'St. Thomas Mount, Chennai', 'Opening and Closing Time': '1pm – 11pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,200 for two'}
# {'Product Name': "Vasco's - Hilton Chennai", 'Cuisines': 'North Indian, Continental, Asian, Italian, Beverages, Desserts', 'Address': 'Hilton Chennai, Guindy, Chennai', 'Opening and Closing Time': 'Opens at 6:30pm', 'Ratings': '4.3', 'Average Cost': '₹4,000 for two'}
# {'Product Name': 'Tositos - Infused Roasted Chicken', 'Cuisines': 'Roast Chicken, Burger, Wraps, Desserts, Beverages', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '11:30am – 11pm (Today)', 'Ratings': '3.8', 'Average Cost': '₹600 for two'}
# {'Product Name': "JC's Cafe", 'Cuisines': 'Cafe, Coffee, Sandwich, Pasta, Burger, Pizza, Desserts, Beverages', 'Address': 'Adyar, Chennai', 'Opening and Closing Time': '9am – 11pm (Today)', 'Ratings': '-', 'Average Cost': '₹1,100 for two'}
# {'Product Name': 'Pizza Hut', 'Cuisines': 'Pizza, Fast Food, Beverages, Desserts', 'Address': 'Triplicane, Chennai', 'Opening and Closing Time': '12midnight – 1am, 11am – 12midnight (Today)', 'Ratings': '3.7', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Seeragam', 'Cuisines': 'South Indian, Biryani, North Indian, Chinese, Desserts, Beverages', 'Address': 'Mylapore, Chennai', 'Opening and Closing Time': '12midnight – 3am, 11am – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'The Black Pearl', 'Cuisines': 'North Indian, Chinese, Mughlai, BBQ, Seafood, Desserts, Biryani', 'Address': 'Sholinganallur, Chennai', 'Opening and Closing Time': 'Opens at 6:30pm', 'Ratings': '4.4', 'Average Cost': '₹1,500 for two'}
# {'Product Name': 'Shout Bar & Cafe', 'Cuisines': 'North Indian, Chinese, Asian, Salad, Pizza, Fast Food', 'Address': 'Ramapuram, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'House Of Billa', 'Cuisines': 'North Indian, Oriental, Biryani, Chinese, Pizza, Fast Food, Seafood, Bar Food', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11am – 12midnight (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,400 for two'}
# {'Product Name': "Writer's Cafe", 'Cuisines': 'Pizza, Pasta, European, Italian, Fast Food, Cafe, Coffee, Beverages', 'Address': 'Gopalapuram, Chennai', 'Opening and Closing Time': '10am – 10pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹450 for two'}
# {'Product Name': 'Waves Bar & Lounge', 'Cuisines': 'Finger Food, North Indian, Continental', 'Address': 'Ramada, Egmore, Chennai', 'Opening and Closing Time': '11am – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹2,300 for two'}
# {'Product Name': 'Coffee? Since 1999', 'Cuisines': 'Coffee, Sandwich, Shake', 'Address': 'Thousand Lights, Chennai', 'Opening and Closing Time': '8am – 11:45pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,400 for two'}
# {'Product Name': 'Cream Story', 'Cuisines': 'Desserts, Ice Cream, Beverages', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '12midnight – 3:30am, 11am – 12midnight (Today)', 'Ratings': '3.9', 'Average Cost': '₹300 for two'}
# {'Product Name': 'That Curry Shop', 'Cuisines': 'South Indian, Biryani, Seafood, Street Food, Desserts', 'Address': 'Adyar, Chennai', 'Opening and Closing Time': '12midnight – 2am, 7am – 12midnight (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'The Square - Novotel', 'Cuisines': 'Continental, North Indian, Asian, Japanese, Fast Food, Shake, Beverages, Desserts', 'Address': 'Novotel Chennai,Sipcot, Chennai', 'Opening and Closing Time': '6am – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹3,000 for two'}
# {'Product Name': 'The Catch @ ECR', 'Cuisines': 'Chinese, Continental, Mexican, Asian, BBQ, Steak, North Indian, Desserts', 'Address': 'Vettuvankeni, Chennai', 'Opening and Closing Time': '11:30am – 11pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹1,100 for two'}
# {'Product Name': 'Gameistry', 'Cuisines': 'Cafe, Pizza, Fast Food, Sichuan, Desserts, Continental, Shake, Beverages', 'Address': 'Egmore, Chennai', 'Opening and Closing Time': 'N/A', 'Ratings': '4.1', 'Average Cost': '₹500 for two'}
# {'Product Name': 'Meenam', 'Cuisines': 'South Indian, North Indian, Biryani, Seafood, Desserts', 'Address': 'Harrisons Hotel, Nungambakkam, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,300 for two'}
# {'Product Name': 'Eko Lyfe - Guilt Free Bistro Cafe', 'Cuisines': 'Fast Food, Salad, Desserts, Shake, Beverages', 'Address': 'Abhiramapuram, Chennai', 'Opening and Closing Time': '9am – 10:30pm (Today)', 'Ratings': '4.9', 'Average Cost': '₹350 for two'}
# {'Product Name': 'Impasta', 'Cuisines': 'Italian, Desserts, Beverages, Pizza, Pasta, Cafe, Continental, Seafood', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '12noon – 10:45pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,400 for two'}
# {'Product Name': 'House of Idlies', 'Cuisines': 'South Indian', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '6:30am – 10pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹200 for two'}
# {'Product Name': 'Coastal Taste Family Restaurant', 'Cuisines': 'South Indian, Kerala, Seafood, Oriental, Shawarma, Biryani, Desserts, Beverages', 'Address': 'Santhome, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹550 for two'}
# {'Product Name': 'Zaitoon Signature', 'Cuisines': 'Arabian, Kebab, Biryani, BBQ, North Indian, Seafood', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11:30am – 11:30pm (Today)', 'Ratings': '3.3', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'Bhangra', 'Cuisines': 'North Indian, Mughlai, Rolls', 'Address': 'Mayajaal Multiplex, Kanathur, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.8', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Paradise Biryani - A Legend Since 1953', 'Cuisines': 'Biryani, Kebab, North Indian, Rolls, Desserts, Chinese', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹500 for two'}
# {'Product Name': 'Mirabilis', 'Cuisines': 'North Indian, Continental, Italian, Beverages', 'Address': 'Injambakkam, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': 'New', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Tulips - Green Park Hotel', 'Cuisines': 'North Indian, Tamil, Chinese, Desserts, Sichuan', 'Address': 'Green Park Hotel, Vadapalani, Chennai', 'Opening and Closing Time': '7am – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'FB Cakes', 'Cuisines': 'Bakery', 'Address': 'Hotel Ashok Residency, Poonamalle, Chennai', 'Opening and Closing Time': '9am – 12midnight (Today)', 'Ratings': '3.8', 'Average Cost': '₹250 for two'}
# {'Product Name': 'Amaravathi', 'Cuisines': 'South Indian, Andhra, Seafood, Biryani', 'Address': 'Gopalapuram, Chennai', 'Opening and Closing Time': '11am – 4pm, 7pm – 11pm (Today)', 'Ratings': '3.7', 'Average Cost': '₹850 for two'}
# {'Product Name': 'Chidambaram New Moorthy Cafe', 'Cuisines': 'Biryani, South Indian, Chettinad, North Indian, Chinese, Seafood, Desserts, Beverages', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹700 for two'}
# {'Product Name': 'Cafe CakeBee', 'Cuisines': 'Cafe, Italian, Bakery, Desserts, Beverages, Shake', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '8am – 11pm (Today)', 'Ratings': '4.4', 'Average Cost': '₹800 for two'}
# {'Product Name': 'The Chennai Sandwich Shop', 'Cuisines': 'Sandwich, Fast Food, Burger, Pizza, Shake, Beverages', 'Address': 'Ramapuram, Chennai', 'Opening and Closing Time': '10am – 2am (Today)', 'Ratings': '4.1', 'Average Cost': '₹400 for two'}
# {'Product Name': 'Sea Tales Restaurant', 'Cuisines': 'Seafood, North Indian, Chinese, Mughlai, Biryani, Beverages, Desserts', 'Address': 'Injambakkam, Chennai', 'Opening and Closing Time': '1pm – 12midnight (Today)', 'Ratings': '3.6', 'Average Cost': '₹900 for two'}
# {'Product Name': 'Rithrak Family Foods', 'Cuisines': 'South Indian, Tamil', 'Address': 'GST Road, Chennai', 'Opening and Closing Time': '7:30am – 10:30pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹200 for two'}
# {'Product Name': 'Big Bang Theory - Bar & Kitchen', 'Cuisines': 'American, Continental, Finger Food, Fast Food, Beverages', 'Address': 'Kodambakkam, Chennai', 'Opening and Closing Time': '1pm – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,900 for two'}
# {'Product Name': 'The High Joint', 'Cuisines': 'Fast Food, Burger, Beverages', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '12:15pm – 12midnight (Today)', 'Ratings': '4.1', 'Average Cost': '₹550 for two'}
# {'Product Name': 'Bay 146 - The Savera Hotel', 'Cuisines': 'Continental, Asian, Seafood, South Indian, Desserts', 'Address': 'The Savera Hotel, RK Salai (Cathedral Road), Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,600 for two'}
# {'Product Name': 'N/A', 'Cuisines': 'N/A', 'Address': 'N/A', 'Opening and Closing Time': 'N/A', 'Ratings': 'N/A', 'Average Cost': 'N/A'}
# {'Product Name': 'Radio Room', 'Cuisines': 'Italian, Continental, Bar Food, Beverages', 'Address': 'Somerset Greenways, Chennai', 'Opening and Closing Time': '12midnight – 3:30am, 12noon – 12midnight (Today)', 'Ratings': '4.4', 'Average Cost': '₹2,500 for two'}
# {'Product Name': 'Crema - A Culinary Affair', 'Cuisines': 'Desserts, Bakery, Italian, Fast Food, Wraps, Pasta, Shake, Beverages', 'Address': 'Besant Nagar, Chennai', 'Opening and Closing Time': '12noon – 10:45pm (Today)', 'Ratings': '4.6', 'Average Cost': '₹550 for two'}
# {'Product Name': 'Fazari', 'Cuisines': 'Arabian, Mandi, BBQ, Chinese, Lebanese, Kerala, Desserts, Beverages', 'Address': 'Tambaram, Chennai', 'Opening and Closing Time': '11:30am – 11:30pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹950 for two'}
# {'Product Name': 'Hotel Bilal', 'Cuisines': 'Biryani, Chinese', 'Address': 'Chromepet, Chennai', 'Opening and Closing Time': '12midnight – 5am, 11am – 11:45pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹300 for two'}
# {'Product Name': 'Beta Game Cafe', 'Cuisines': 'Fast Food, Rolls, Momos', 'Address': 'Avadi, Chennai', 'Opening and Closing Time': '12midnight – 2am, 11am – 12midnight (Today)', 'Ratings': '3.5', 'Average Cost': '₹150 for two'}
# {'Product Name': 'Willows - The Westin', 'Cuisines': 'Finger Food, Continental, North Indian, Beverages', 'Address': 'The Westin Chennai, Velachery, Chennai', 'Opening and Closing Time': '3pm – 11:30pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹3,600 for two'}
# {'Product Name': 'Malgudi - The Savera Hotel', 'Cuisines': 'South Indian, Kerala, Tamil, Andhra, Biryani, Seafood, Desserts, Beverages', 'Address': 'The Savera Hotel, RK Salai (Cathedral Road), Chennai', 'Opening and Closing Time': '12:30pm – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹3,000 for two'}
# {'Product Name': 'Eating Circles', 'Cuisines': 'South Indian', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '7am – 11pm (Today)', 'Ratings': '4.6', 'Average Cost': '₹350 for two'}
# {'Product Name': 'The Noodle Theory', 'Cuisines': 'Chinese, Japanese, Asian, Desserts, Beverages', 'Address': 'Kilpauk, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹600 for two'}
# {'Product Name': 'Gangotree', 'Cuisines': 'Mithai, Street Food', 'Address': 'Gopalapuram, Chennai', 'Opening and Closing Time': '9am – 11pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹200 for two'}
# {'Product Name': '10 Downing Street', 'Cuisines': 'Finger Food, North Indian, Oriental, Continental, Beverages', 'Address': 'T. Nagar, Chennai', 'Opening and Closing Time': '12noon – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,800 for two'}
# {'Product Name': 'Arabian Garden Sea Food Restaurant', 'Cuisines': 'Biryani, Juices', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11:30am – 11:30pm (Today)', 'Ratings': '3.2', 'Average Cost': '₹400 for two'}
# {'Product Name': 'Sree Akshayam', 'Cuisines': 'South Indian, North Indian, Chinese, Chettinad, Salad, Sichuan, Desserts, Beverages', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '7am – 11pm (Today)', 'Ratings': '3.5', 'Average Cost': '₹850 for two'}
# {'Product Name': 'Madurai Simmakkal Konar Kadai', 'Cuisines': 'South Indian, Tamil, Biryani, Seafood, Beverages', 'Address': 'Egmore, Chennai', 'Opening and Closing Time': '11:15am – 10:30pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹950 for two'}
# {'Product Name': 'Tipsy Dive Bar', 'Cuisines': 'Bar Food, South Indian, Continental, Italian, Chinese, Desserts, Beverages', 'Address': 'Potheri, Chennai', 'Opening and Closing Time': '12noon – 11:30pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'Aziza Restaurant', 'Cuisines': 'Thai, Asian, North Indian, South Indian, Chinese, Desserts, Beverages', 'Address': 'Nungambakkam, Chennai', 'Opening and Closing Time': '11:30am – 11:30pm (Today)', 'Ratings': '4.0', 'Average Cost': '₹1,200 for two'}
# {'Product Name': 'JCS Food Point', 'Cuisines': 'Fast Food, Pizza, Sandwich, Burger', 'Address': 'Thiruvallur, Chennai', 'Opening and Closing Time': '11am – 10:30pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹300 for two'}
# {'Product Name': 'Canadian 2 For 1 Pizza', 'Cuisines': 'Pizza, Fast Food', 'Address': 'Besant Nagar, Chennai', 'Opening and Closing Time': '12midnight – 2am, 12noon – 12midnight (Today)', 'Ratings': '3.1', 'Average Cost': '₹500 for two'}
# {'Product Name': 'Achayathis Restaurant', 'Cuisines': 'Kerala, South Indian', 'Address': 'Maduravoyal, Chennai', 'Opening and Closing Time': '9am – 11pm (Today)', 'Ratings': 'New', 'Average Cost': '₹400 for two'}
# {'Product Name': 'Shri Gowri Krishnaa', 'Cuisines': 'South Indian, North Indian, Chinese, Sichuan, Biryani, Beverages', 'Address': 'Gopalapuram, Chennai', 'Opening and Closing Time': '6:30am – 11pm (Today)', 'Ratings': '3.8', 'Average Cost': '₹500 for two'}
# {'Product Name': 'Narmada Chain of Restaurants', 'Cuisines': 'Biryani, Andhra, North Indian', 'Address': 'Sholinganallur, Chennai', 'Opening and Closing Time': '12midnight – 2am, 11:30am – 12midnight (Today)', 'Ratings': '4.2', 'Average Cost': '₹800 for two'}
# {'Product Name': 'Anandha Vilas - Flavours Of Kongunadu', 'Cuisines': 'South Indian, Tamil, Seafood, Biryani', 'Address': 'Nandanam, Chennai', 'Opening and Closing Time': '12midnight – 2am, 11am – 4pm, 7pm – 12midnight (Today)', 'Ratings': '4.4', 'Average Cost': '₹700 for two'}
# {'Product Name': 'New Sindhu Fast Food And Tiffin Center', 'Cuisines': 'South Indian, Chinese, Biryani', 'Address': 'Pallikaranai, Chennai', 'Opening and Closing Time': 'Opens at 11:45pm', 'Ratings': '3.7', 'Average Cost': '₹250 for two'}
# {'Product Name': 'Annam Cafe - By Purple Chameleon', 'Cuisines': 'South Indian, North Indian, Oriental', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '11:30am – 10:30pm (Today)', 'Ratings': '4.1', 'Average Cost': '₹1,500 for two'}
# {'Product Name': "Fisherman's Signature", 'Cuisines': 'Chinese, South Indian', 'Address': 'Chetpet, Chennai', 'Opening and Closing Time': '12noon – 10:30pm (Today)', 'Ratings': '-', 'Average Cost': '₹450 for two'}
# {'Product Name': 'Padmam Veg Restaurant', 'Cuisines': 'South Indian, North Indian', 'Address': 'Saligramam, Chennai', 'Opening and Closing Time': '7am – 11:30pm (Today)', 'Ratings': '3.6', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Thenmanam', 'Cuisines': 'North Indian, South Indian, Mughlai, Seafood, Biryani, Chinese, Desserts', 'Address': 'Anna Nagar West, Chennai', 'Opening and Closing Time': '12noon – 4pm, 7pm – 11pm (Today)', 'Ratings': '3.1', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Albatraz Takeaway', 'Cuisines': 'Mughlai, Chinese, Seafood, South Indian', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '12:30pm – 11pm (Today)', 'Ratings': '-', 'Average Cost': '₹300 for two'}
# {'Product Name': 'Crust & Co.', 'Cuisines': 'Cafe, Coffee, South Indian, Italian, Sandwich, Fast Food, Desserts, Beverages', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '10am – 10pm (Today)', 'Ratings': '-', 'Average Cost': '₹1,550 for two'}
# {'Product Name': 'Kaaraikudi', 'Cuisines': 'South Indian, North Indian, Biryani, Seafood, Mughlai, Desserts, Beverages', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '12noon – 10:30pm (Today)', 'Ratings': '3.7', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Al Hafa Multi Cuisine Restaurant', 'Cuisines': 'Biryani, Chinese, North Indian, Mughlai, Desserts', 'Address': 'Ashok Nagar, Chennai', 'Opening and Closing Time': '12:30pm – 10:30pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹500 for two'}
# {'Product Name': 'Avartana - ITC Grand Chola', 'Cuisines': 'South Indian', 'Address': 'ITC Grand Chola, Guindy, Chennai', 'Opening and Closing Time': 'Opens at 7pm', 'Ratings': '4.9', 'Average Cost': '₹7,000 for two'}
# {'Product Name': 'Break Your Burger', 'Cuisines': 'Burger', 'Address': 'Mogappair, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '-', 'Average Cost': '₹500 for two'}
# {'Product Name': 'Zaitoon Restaurant & Grill', 'Cuisines': 'Healthy Food, Chinese, Seafood, North Indian, Arabian, Ice Cream, Beverages', 'Address': 'Selaiyur, Chennai', 'Opening and Closing Time': '11am – 11:30pm (Today)', 'Ratings': '3.2', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Andhikkadai', 'Cuisines': 'South Indian, Beverages, Shake, Desserts', 'Address': 'Velachery, Chennai', 'Opening and Closing Time': '7am – 10pm (Today)', 'Ratings': '4.5', 'Average Cost': '₹300 for two'}
# {'Product Name': 'The Fat Boy', 'Cuisines': 'Pizza, Sandwich, Fast Food, Desserts, Shake, Beverages', 'Address': 'Alwarpet, Chennai', 'Opening and Closing Time': '12noon – 1am (Today)', 'Ratings': '4.3', 'Average Cost': '₹1,300 for two'}
# {'Product Name': 'Dhani', 'Cuisines': 'North Indian, South Indian, Continental, Asian, Chinese, Pizza, Desserts', 'Address': 'Kaldan Samudhra Palace, Chennai', 'Opening and Closing Time': 'Opens at 7pm', 'Ratings': '4.2', 'Average Cost': '₹5,700 for two'}
# {'Product Name': 'Library Blu - The Leela Palace', 'Cuisines': 'Finger Food', 'Address': 'The Leela Palace, MRC Nagar, Chennai', 'Opening and Closing Time': 'Opens at 5pm', 'Ratings': '4.9', 'Average Cost': '₹3,500 for two'}
# {'Product Name': 'Cafe Of Tales', 'Cuisines': 'Cafe, Coffee, Italian, Continental, Waffle, Desserts, Beverages', 'Address': 'Ashok Nagar, Chennai', 'Opening and Closing Time': '1:30pm – 11pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,000 for two'}
# {'Product Name': 'Vapor - Feathers, A Radha Hotel', 'Cuisines': 'North Indian, Continental, Salad, Burger, Pizza, Desserts, Shake, Beverages', 'Address': 'Feathers, A Radha Hotel, Chennai', 'Opening and Closing Time': '12noon – 11pm (Today)', 'Ratings': '4.2', 'Average Cost': '₹1,700 for two'}
# {'Product Name': 'Virunthombal Chettinadu', 'Cuisines': 'Chettinad, Biryani, Chinese, Ice Cream, Beverages', 'Address': 'Mahabalipuram, Chennai', 'Opening and Closing Time': '11am – 11pm (Today)', 'Ratings': '3.9', 'Average Cost': '₹700 for two'}
# {'Product Name': 'Melt', 'Cuisines': 'Street Food, Fast Food, Sandwich, Beverages', 'Address': 'Thousand Lights, Chennai', 'Opening and Closing Time': '12midnight – 3am, 4:15pm – 12midnight (Today)', 'Ratings': '3.4', 'Average Cost': '₹250 for two'}
# {'Product Name': 'Terrace - By The Living Room', 'Cuisines': 'Continental, Italian, Desserts, Beverages', 'Address': 'Anna Nagar East, Chennai', 'Opening and Closing Time': '4pm – 11pm (Today)', 'Ratings': '4.3', 'Average Cost': '₹2,000 for two'}
# {'Product Name': 'Arabian Hut', 'Cuisines': 'Fast Food, BBQ, Shawarma, Biryani', 'Address': 'Phoenix Market City, Velachery, Chennai', 'Opening and Closing Time': '10am – 10:30pm (Today)', 'Ratings': '3.4', 'Average Cost': '₹700 for two'}
# {'Product Name': 'Zodiac - The Accord Metropolitan', 'Cuisines': 'Finger Food', 'Address': 'The Accord Metropolitan, T. Nagar, Chennai', 'Opening and Closing Time': '4pm – 12midnight (Today)', 'Ratings': '3.9', 'Average Cost': '₹1,600 for two'}
# {'Product Name': 'Tutto Bene - Health Cafe By Little Italy', 'Cuisines': 'Cafe, Coffee, Bakery, Italian, Continental, Mexican, Desserts, Beverages', 'Address': 'Besant Nagar, Chennai', 'Opening and Closing Time': '10am – 11pm (Today)', 'Ratings': '3.8', 'Average Cost': '₹1,100 for two'}
# Data saved to zomato_books1.csv

# %%
import pandas as pd

# read Excel
data = pd.read_excel('zomato_books1.xlsx')
data
# Out:
#                               Restaurant Name Primary Cuisines  \
# 0                                Secret Story     North Indian
# 1                                     TapasMe            Asian
# 2                          Lord of the Drinks          Italian
# 3                      Goldmanâ€™s Steakhouse         American
# 4                                 Sin & Tonic     North Indian
# ..                                        ...              ...
# 161                                      Melt      Street Food
# 162              Terrace - By The Living Room      Continental
# 163                               Arabian Hut        Fast Food
# 164          Zodiac - The Accord Metropolitan      Finger Food
# 165  Tutto Bene - Health Cafe By Little Italy             Cafe
#
#     Secondary Cuisines                                     Other Cuisines  \
# 0              Chinese                                 Italian, Fast Food
# 1             European                  Continental, Desserts, Beverages,
# 2          Continental        North Indian, Japanese, Desserts, Beverages
# 3              Mexican              Steak, Fast Food, Beverages, Desserts
# 4              Italian             BBQ, Wraps, Pizza, Desserts, Bar Food,
# ..                 ...                                                ...
# 161          Fast Food                                Sandwich, Beverages
# 162            Italian                                Desserts, Beverages
# 163                BBQ                                  Shawarma, Biryani
# 164                Nil                                                Nil
# 165             Coffee   Bakery, Italian, Continental, Mexican, Desser...
#
#                                Address Opening Time Closing Time  Ratings  \
# 0                        Nungambakkam      12:00:00     00:00:00      4.2
# 1                     Anna Nagar West      12:00:00     23:00:00      4.5
# 2                        Nungambakkam      12:00:00     00:00:00      4.2
# 3                        Nungambakkam      11:00:00     23:30:00      4.2
# 4                            T. Nagar      12:00:00     00:00:00      4.5
# ..                                 ...          ...          ...      ...
# 161                   Thousand Lights      00:00:00     16:15:00      3.4
# 162                   Anna Nagar East      16:00:00     23:00:00      4.3
# 163     Phoenix Market City Velachery      10:00:00     22:30:00      3.4
# 164  The Accord Metropolitan T. Nagar      16:00:00     00:00:00      3.9
# 165                      Besant Nagar      10:00:00     23:00:00      3.8
#
#      Average Cost
# 0            2000
# 1            1500
# 2            2500
# 3            2500
# 4            2700
# ..            ...
# 161           250
# 162          2000
# 163           700
# 164          1600
# 165          1100
#
# [166 rows x 9 columns]

# %%
data.tail(100)
# Out:
#                               Restaurant Name Primary Cuisines  \
# 66                                Burger King           Burger
# 67                                Chinese Wok          Chinese
# 68                                  Una Villa          Italian
# 69                               Royal Palate      Continental
# 70                            Truly Herbivore     North Indian
# ..                                        ...              ...
# 161                                      Melt      Street Food
# 162              Terrace - By The Living Room      Continental
# 163                               Arabian Hut        Fast Food
# 164          Zodiac - The Accord Metropolitan      Finger Food
# 165  Tutto Bene - Health Cafe By Little Italy             Cafe
#
#     Secondary Cuisines                                     Other Cuisines  \
# 66           Fast Food                                         Beverages,
# 67               Momos                                                Nil
# 68               Pasta                 Sandwich, Pizza, Burger, Beverages
# 69            European      South Indian, North Indian, Chinese, Desserts
# 70        South Indian   Continental, Italian, Maharashtrian, Desserts...
# ..                 ...                                                ...
# 161          Fast Food                                Sandwich, Beverages
# 162            Italian                                Desserts, Beverages
# 163                BBQ                                  Shawarma, Biryani
# 164                Nil                                                Nil
# 165             Coffee   Bakery, Italian, Continental, Mexican, Desser...
#
#                                Address Opening Time Closing Time  Ratings  \
# 66       Forum Vijaya Mall Vadapalani      10:00:00     23:00:00      3.9
# 67                              Porur      00:00:00     11:00:00      4.0
# 68                       Nungambakkam      10:00:00     22:00:00      0.0
# 69           Ambica Empire Vadapalani      00:00:00     00:00:00      3.5
# 70                        Ashok Nagar      00:00:00     00:00:00      4.3
# ..                                 ...          ...          ...      ...
# 161                   Thousand Lights      00:00:00     16:15:00      3.4
# 162                   Anna Nagar East      16:00:00     23:00:00      4.3
# 163     Phoenix Market City Velachery      10:00:00     22:30:00      3.4
# 164  The Accord Metropolitan T. Nagar      16:00:00     00:00:00      3.9
# 165                      Besant Nagar      10:00:00     23:00:00      3.8
#
#      Average Cost
# 66            300
# 67            700
# 68           1000
# 69           1000
# 70           1000
# ..            ...
# 161           250
# 162          2000
# 163           700
# 164          1600
# 165          1100
#
# [100 rows x 9 columns]

# %%
#Load the scraped data into MySQL

# %%
#pip install mysql-connector-python pandas
# Out:
# Requirement already satisfied: mysql-connector-python in c:\users\vkavi\anaconda3\lib\site-packages (9.0.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: pandas in c:\users\vkavi\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\vkavi\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\vkavi\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\vkavi\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\vkavi\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\vkavi\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd
import mysql.connector
from mysql.connector import errorcode

# Load the cleaned dataset
data = pd.read_excel('zomato_books1.xlsx')

# MySQL database connection
config = {
    "user": "root",
    "password": "Mysql@1992",
    "host": "localhost",
    "database": "Zomato",
    "raise_on_warnings": True
}

try:
    # Connect to the database
    connection = mysql.connector.connect(**config)
    cursor = connection.cursor()

    # Insert data into the Products table
    for index, row in data.iterrows():
        cursor.execute("""
            INSERT INTO Restaurants (`Restaurant Name`, `Primary Cuisines`, `Secondary Cuisines`, `Other Cuisines`, `Address`, `Opening Time`, `Closing Time`, `Ratings`, `Average Cost`)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
        """, (
            row['Restaurant Name'],
            row['Primary Cuisines'],  
            row['Secondary Cuisines'],
            row['Other Cuisines'],
            row['Address'],  
            row['Opening Time'],
            row['Closing Time'],
            row['Ratings'],
            row['Average Cost']
        ))

    # Commit the transaction
    connection.commit()

except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print("Database does not exist")
    else:
        print(err)
finally:
    cursor.close()
    connection.close()
